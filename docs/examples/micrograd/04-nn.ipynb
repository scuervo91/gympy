# %%
## Neurons

# %%
from gympy.autograd import Neuron, Layer, MLP
from random import uniform

# %%
inputs = [uniform(10,100) for i in range(5)]
inputs
# Out:
# [81.3526576669605,
#  16.12182906218144,
#  48.988377417597725,
#  15.728648868123866,
#  57.19573439465374]

# %%
nn = MLP(5,[3,4,5,4,1],['relu','relu','relu','relu','sigmoid'])

# %%
out = nn(inputs)
out
# Out:
# [Value(data=0.872924720909257)]

# %%
out[0].draw_dot()

# %%
nn.layers[0].outputs
# Out:
# 3
